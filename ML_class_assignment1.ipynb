# %% [markdown]
# Krishna Purwar
# 21BPS1367

# %%
import numpy as np
import pandas as pd
from numpy import nan

# %% [markdown]
# ## Task 1:
# ## Create a pandas dataframe (DataFrame name as 'df') (10 observation and 5 features)

# %%
# Stock Market: name of companies, name of the sector, market cap, 5Yr CAGR, EPS

stocks = {'Name':
            ['VBL', 'KPITTECH', 'POLYMED', 'BAJFINANCE', 'HDFCBANK',
             'ASIANPAINT', 'NLCINDIA', 'KALYANKJIL', 'CEATLTD', 'IDFCFIRSTB'],
          'Sector' :
            ['Consumer Staples', 'IT', 'Healthcare', 'Finincial', 'Finincial',
             'Materials', 'Materials', 'Consumer Discretionary', 'Consumer Discretionary', 'Finincial'],
          'Market Cap(in Cr.)' :
            [ 113525, 31052, 13547, 436391, 1181498, 312514, 17880, 21734, 9302, 60448],
          '5Yr CAGR(%)' :
            [49, nan, 46, 19, 9, 19, 11, nan, 10, 14],
          'EPS' :
            [14.46, 15.68, 22.41, 203.97, 87.43, 48.37, 8.39, 4.55, 79.49, 4.23]
     }

# %%
df = pd.DataFrame(stocks)

# %%
df.head()
# Out:
#          Name            Sector  Market Cap(in Cr.)  5Yr CAGR(%)     EPS
# 0         VBL  Consumer Staples              113525         49.0   14.46
# 1    KPITTECH                IT               31052          NaN   15.68
# 2     POLYMED        Healthcare               13547         46.0   22.41
# 3  BAJFINANCE         Finincial              436391         19.0  203.97
# 4    HDFCBANK         Finincial             1181498          9.0   87.43

# %% [markdown]
# ## Task 2:
# ## Check the info of 'df'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10 non-null     object
#  1   Sector              10 non-null     object
#  2   Market Cap(in Cr.)  10 non-null     int64
#  3   5Yr CAGR(%)         8 non-null      float64
#  4   EPS                 10 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 528.0+ bytes

# %% [markdown]
# ## Task 3:
# ## Check the descriptive statistics of 'df'

# %%
df.describe()
# Out:
#        Market Cap(in Cr.)  5Yr CAGR(%)         EPS
# count        1.000000e+01     8.000000   10.000000
# mean         2.197891e+05    22.125000   48.898000
# std          3.681086e+05    16.128391   62.416245
# min          9.302000e+03     9.000000    4.230000
# 25%          1.884350e+04    10.750000    9.907500
# 50%          4.575000e+04    16.500000   19.045000
# 75%          2.627668e+05    25.750000   71.710000
# max          1.181498e+06    49.000000  203.970000

# %% [markdown]
# ## Task 4:
# ## Check the 4th index observation with 'loc' slicing operator.

# %%
df.loc[4]
# Out:
# Name                   HDFCBANK
# Sector                Finincial
# Market Cap(in Cr.)      1181498
# 5Yr CAGR(%)                 9.0
# EPS                       87.43
# Name: 4, dtype: object

# %% [markdown]
# ## Task 5:
# ##Check the null values in your 'df'

# %%
df.isnull()
# Out:
#     Name  Sector  Market Cap(in Cr.)  5Yr CAGR(%)    EPS
# 0  False   False               False        False  False
# 1  False   False               False         True  False
# 2  False   False               False        False  False
# 3  False   False               False        False  False
# 4  False   False               False        False  False
# 5  False   False               False        False  False
# 6  False   False               False        False  False
# 7  False   False               False         True  False
# 8  False   False               False        False  False
# 9  False   False               False        False  False

# %%
df.isnull().any()
# Out:
# Name                  False
# Sector                False
# Market Cap(in Cr.)    False
# 5Yr CAGR(%)            True
# EPS                   False
# dtype: bool
